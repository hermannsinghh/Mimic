# %% [markdown]
# # mimic-bench: Leaderboard
#
# Submit results and view the leaderboard.

# %%
from mimic_bench.leaderboard import submit, display, get_entries

# Assume `results` is a BenchmarkResult from bench.run()
# submit(results, model_name="my-model-v1", notes="Claude Opus with SEC RAG")

display()

# %%
import json
entries = get_entries()
print(f"{len(entries)} entries on leaderboard")
if entries:
    print(json.dumps(entries[0], indent=2))
